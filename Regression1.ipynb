# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 3 from sklearn.linear_model import LinearRegression
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.7.2

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

# %%
# Example data
X = np.array([[1], [2], [3], [4], [5]])  # hours studied
y = np.array([30, 40, 50, 60, 70])       # exam scores

# %%
# Create and train model
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
# Check slope (m) and intercept (c)
print("Slope (m):", model.coef_)
print("Intercept (c):", model.intercept_)
# Out:
# Slope (m): [10.]
# Intercept (c): 20.000000000000007

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# Sample data: X = hours studied, y = exam score
X = np.array([[1], [2], [3], [4], [5]])
y = np.array([30, 40, 50, 60, 70])

# %%
# Create and train model
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
# Predict score for 6 hours study
pred = model.predict([[6]])
print("Predicted score for 6 hours study:", pred)
# Out:
# Predicted score for 6 hours study: [80.]

# %%
# Plot
plt.scatter(X, y, color='blue')
plt.plot(X, model.predict(X), color='red')
plt.xlabel("Hours Studied")
plt.ylabel("Exam Score")
plt.show()
